# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %% [markdown]
# # importation

# %%
import os.path
import base64
import json
import pandas as pd
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# %%
# Défénir les permissons demandées pour acceder a gmail
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# %%
def authenticate_gmail_api():
    """Authentifie l'utilisateur et renvoie un service API Gmail."""
    creds = None
    # Le fichier token.json stocke les jetons d'accès et d'actualisation de l'utilisateur
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # Si il n'y a pas de (valide) jetons disponibles, laissez l'utilisateur se connecter.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('../credentials.json', SCOPES)
            creds = flow.run_local_server(port=8081)
        # Enregistrer les jetons pour la prochaine exécution
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    # Construire le service Gmail
    service = build('gmail', 'v1', credentials=creds)
    return service

# %%
service = authenticate_gmail_api()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=455190904108-7neb8q48h71eg7jqclts7n6kopf6hsi6.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8081%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly&state=GTUapnSkiQMogylIE2FxDkdL5HTA7o&access_type=offline

# %%
def get_email_info(service, label_id, max_results=200):
    """Récupère les informations des emails pour un label donné."""
    try:
        email_infos = []
        next_page_token = None

        while len(email_infos) < max_results:
            results = service.users().messages().list(
                userId='me', labelIds=[label_id], maxResults=100, pageToken=next_page_token
            ).execute()
            messages = results.get('messages', [])

            if not messages:
                print(f'No more messages found.')
                break

            for message in messages:
                msg = service.users().messages().get(userId='me', id=message['id']).execute()

                # Récupération des informations du message
                headers = msg['payload']['headers']
                snippet = msg.get('snippet', '')

                from_email = next(header['value'] for header in headers if header['name'] == 'From')
                subject = next((header['value'] for header in headers if header['name'] == 'Subject'), '(No Subject)')
                labels = msg.get('labelIds', [])
                has_attachments = 'parts' in msg['payload']

                email_info = {
                    'From': from_email,
                    'Subject': subject,
                    'Snippet': snippet,
                    'Labels': labels,
                    'Has Attachments': has_attachments,
                }

                email_infos.append(email_info)
                if len(email_infos) >= max_results:
                    break

            next_page_token = results.get('nextPageToken')
            if not next_page_token:
                break

        for email_info in email_infos:
            print(json.dumps(email_info, indent=1))

        return email_infos

    except Exception as error:
        print(f'An error occurred: {error}')

# %%
inbox_emails = get_email_info(service, 'INBOX')
spam_emails = get_email_info(service, 'SPAM')
# Out:
# An error occurred: name 'label_name' is not defined
# An error occurred: name 'label_name' is not defined

# %%
df_inbox = pd.DataFrame(inbox_emails)
df_inbox
# Out:
#                                                  From  \
# 0              Typology Paris <no-reply@typology.com>
# 1       LinkedIn <notifications-noreply@linkedin.com>
# 2              Typology Paris <no-reply@typology.com>
# 3    France travail <Service-candidat@pole-emploi.fr>
# 4              Typology Paris <no-reply@typology.com>
# 5                       Epitech <toulouse@epitech.eu>
# 6   France Travail <pole-emploi@noreply-pole-emplo...
# 7              Crazy Factory <info@crazy-factory.com>
# 8              Typology Paris <no-reply@typology.com>
# 9              Crazy Factory <info@crazy-factory.com>
# 10             Crazy Factory <info@crazy-factory.com>
# 11             Crazy Factory <info@crazy-factory.com>
# 12              LinkedIn <jobs-listings@linkedin.com>
# 13                 VALERIE VIDONI <vvidoni@jehann.fr>
# 14          EPITECH <no-reply-candidature@epitech.eu>
# 15          EPITECH <no-reply-candidature@epitech.eu>
# 16              LinkedIn <jobs-listings@linkedin.com>
# 17              LinkedIn <jobs-listings@linkedin.com>
# 18              LinkedIn <jobs-listings@linkedin.com>
# 19  "Emilie Violé-chavez" <emilie.viole-chavez@epi...
# 20  Charlotte Bejaoui vidal <charlotte.bejaoui-vid...
# 21                   CVEC-ne-pas-repondre@lescrous.fr
# 22                   noreply-payfip@sips-services.com
# 23              LinkedIn <jobs-listings@linkedin.com>
# 24                     SHEIN <info@news.fr.shein.com>
# 25                 VALERIE VIDONI <vvidoni@jehann.fr>
# 26                Discord <notifications@discord.com>
# 27              LinkedIn <jobs-listings@linkedin.com>
# 28  Alertes LinkedIn Jobs <jobalerts-noreply@linke...
# 29  "*OCCITANIE Prévention Fraudes" <preventionfra...
# 30              LinkedIn <jobs-listings@linkedin.com>
# 31  Alertes LinkedIn Jobs <jobalerts-noreply@linke...
# 32                        GitHub <noreply@github.com>
# 33                Thales Group <thales@myworkday.com>
# 34  "Équipe de recrutement de Business & Decision"...
# 35               Epitech <mscpro-toulouse@epitech.eu>
# 36                Thales Group <thales@myworkday.com>
# 37          EPITECH <no-reply-candidature@epitech.eu>
# 38          EPITECH <no-reply-candidature@epitech.eu>
# 39   France Travail <service-candidat@pole-emploi.fr>
# 40                   APEC <noreply@diffusion.apec.fr>
# 41  "Enquête France Travail" <enquetefrancetravail...
# 42              LinkedIn <jobs-listings@linkedin.com>
# 43  Alertes LinkedIn Jobs <jobalerts-noreply@linke...
# 44  "Airbus Human Resources (Do Not Reply)" <ag@my...
# 45   France travail <Service-candidat@pole-emploi.fr>
# 46  France Travail <ne-pas-repondre-message@france...
# 47  France Travail <ne-pas-repondre-message@france...
# 48  "Intermarché" <intermarche@infos.intermarche.com>
# 49                         Doctorat <noreply@adum.fr>
#
#                                               Subject  \
# 0                    Votre prescription personnalisée
# 1                  Vous apparaissez dans 9 recherches
# 2                        Votre prescription est prête
# 3   Vous avez reçu un courrier " Relevé de situati...
# 4   Typologie AE(-) : Ce qu’ils pensent de nos pro...
# 5   Epitech : Toute l'actualité du campus de Toulouse
# 6         Information : absence de votre conseillère.
# 7      Confirmation d’envoi – Votre commande 15914622
# 8                        Votre prescription est prête
# 9                  Votre numéro de commande: 15914622
# 10                 Votre numéro de commande: 15914622
# 11                         Votre nouveau mot de passe
# 12  Poste de Data Scientist chez Capgemini : recru...
# 13        [Jehann] Votre candidature formation DEV IA
# 14      [EPITECH] - Finalisation de votre inscription
# 15      [EPITECH] - Finalisation de votre inscription
# 16  Poste de Applied Data Scientist chez Microsoft...
# 17  Poste de Applied Data Scientist chez Microsoft...
# 18  Poste de ALTERNANCE 2024 - Développeur BI F/H ...
# 19                             RE: Pieces inscription
# 20           Réponse automatique : Pieces inscription
# 21          Cvec.etudiant.gouv.fr - Votre attestation
# 22  Ticket de paiement - Référence : CVEC400000TOU...
# 23  Poste de French Speakers (Remote) chez Sigma A...
# 24  Dernières heures avant que ces offres n'expire...
# 25                         [Jehann] Votre candidature
# 26                  icypada2522 t'a envoyé un message
# 27  Capgemini recrute pour le poste suivant : Data...
# 28            7 nouvelles offres d’emploi pour “data”
# 29              Contrôle dossier 24HPB047 - 4679193E
# 30  Avient Corporation recrute pour le poste suiva...
# 31            6 nouvelles offres d’emploi pour “data”
# 32                 [GitHub] Please verify your device
# 33  Thales Careers - ALTERNANCE - Datascientist- F...
# 34                          Suite à votre candidature
# 35  Epitech : toute l'actualité du campus de Toulouse
# 36  Thales Careers - Alternance – Data Analyst et ...
# 37            [EPITECH] - Finalisez votre inscription
# 38            [EPITECH] - Finalisez votre inscription
# 39  Votre rendez-vous avec un conseiller France Tr...
# 40       Optimisez la visibilité de votre profil Apec
# 41  Suite à votre dernier échange par mail avec vo...
# 42  Le poste de ALT 2024 Apprenti Data Analyst che...
# 43  “Analyste de données” : AGSI-NET - Jobs - Data...
# 44  AIRBUS - Your application status has been updated
# 45  Vous avez reçu un courrier " RDV entretien d'a...
# 46  France Travail - Conversation n°  202406141521...
# 47     France Travail vous propose une offre d’emploi
# 48                       Votre commande est validée !
# 49  sylvia.bouaskeur@univ-tlse3.fr Enquête Inserti...
#
#                                               Snippet  \
# 0   Découvrez vos résultats ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ...
# 1   Des personnes recherchent vos compétences ͏ ͏ ...
# 2   Découvrez votre routine personnalisée ͏ ͏ ͏ ͏ ...
# 3   France Travail Candidat Bonjour, Vous avez reç...
# 4   Leurs avis valent toutes les recommandations. ...
# 5   Consulter cet email en ligne Epitech : Oui à l...
# 6   France Travail Candidat Bonjour, Nous vous inf...
# 7   Bonjour PICOT, Nous sommes ravis de t&#39;anno...
# 8   Découvrez votre routine personnalisée ͏ ͏ ͏ ͏ ...
# 9   Confirmation de commande Merci pour votre comm...
# 10  Confirmation de commande Merci pour votre comm...
# 11  RÉINITIALISER LE MOT DE PASSE Bonjour PICOT Mé...
# 12  Mélanie, voici les meilleures opportunités cho...
# 13  Bonjour, En réponse à votre candidature pour u...
# 14  Bonjour Mélanie PICOT, Nous vous confirmons la...
# 15  Bonjour Mélanie PICOT, Nous vous confirmons la...
# 16  Mélanie, 5 ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏...
# 17  Vos compétences semblent correspondre à ce pos...
# 18  Vos compétences pourraient correspondre à ce p...
# 19  Bonjour Madame, J&#39;accuse réception de votr...
# 20  Bonjour, En arrêt, je vous prie d&#39;adresser...
# 21  Madame, Monsieur, Nous avons bien enregistré v...
# 22  Confirmation de paiement CENTRE REGIONAL DES O...
# 23  Mélanie, 5 ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏...
# 24  Soyez à la pointe de la mode. Le nouveau style...
# 25  Bonjour, En réponse à votre candidature pour u...
# 26  Tu as reçu 1 nouveau message @IcyPada Voir les...
# 27  Votre profil correspond peut-être à l&#39;offr...
# 28  Voir les offres d&#39;emploi - Toulouse ͏ ͏ ͏ ...
# 29  Objet : Contrôle dossier / demande de pièces R...
# 30  Votre profil correspond peut-être à l&#39;offr...
# 31  Voir les offres d&#39;emploi - Toulouse ͏ ͏ ͏ ...
# 32  Hey MelanieP31! A sign in attempt requires fur...
# 33  Dear Mélanie Picot, We have reviewed your appl...
# 34  ​​​​​​​​​​ Bonjour Melanie, Nous vous remercio...
# 35  Consulter cet email en ligne Epitech : Oui à l...
# 36  Dear Mélanie Picot, We have reviewed your appl...
# 37  Bonjour Mélanie PICOT, Vous allez intégrer not...
# 38  Bonjour Mélanie PICOT, Vous allez intégrer not...
# 39  France Travail Candidat Bonjour, N&#39;oubliez...
# 40  Bonjour, Votre Profil Apec est publié dans not...
# 41  Suite à votre dernier échange par mail avec vo...
# 42  ALT 2024 Apprenti Data Analyst chez Airbus : J...
# 43  Data Analyst - Confirmé (H/F) chez AGSI-NET - ...
# 44  Subject: Mélanie Picot ‎- JR10256013 ALT 2024 ...
# 45  France Travail Candidat Bonjour, Vous avez reç...
# 46  Logo Marianne Logo France Travail Bonjour, Je ...
# 47  France Travail - Accueil Candidat Bonjour MELA...
# 48  Votre commande sur intermarche.com est bien en...
# 49  English below Bonjours à toutes et tous, Comme...
#
#                                           Labels  Has Attachments
# 0              [UNREAD, CATEGORY_UPDATES, INBOX]             True
# 1               [UNREAD, CATEGORY_SOCIAL, INBOX]             True
# 2   [UNREAD, IMPORTANT, CATEGORY_UPDATES, INBOX]             True
# 3                      [CATEGORY_UPDATES, INBOX]            False
# 4           [CATEGORY_PROMOTIONS, UNREAD, INBOX]             True
# 5                     [CATEGORY_PERSONAL, INBOX]             True
# 6           [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 7              [UNREAD, CATEGORY_UPDATES, INBOX]            False
# 8                      [CATEGORY_UPDATES, INBOX]             True
# 9   [UNREAD, IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 10  [UNREAD, IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 11          [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 12                      [CATEGORY_SOCIAL, INBOX]             True
# 13         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 14         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 15         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 16              [UNREAD, CATEGORY_SOCIAL, INBOX]             True
# 17              [UNREAD, CATEGORY_SOCIAL, INBOX]             True
# 18                      [CATEGORY_SOCIAL, INBOX]             True
# 19         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 20         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 21                    [CATEGORY_PERSONAL, INBOX]             True
# 22                    [CATEGORY_PERSONAL, INBOX]             True
# 23                      [CATEGORY_SOCIAL, INBOX]             True
# 24                  [CATEGORY_PROMOTIONS, INBOX]             True
# 25         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 26                     [CATEGORY_UPDATES, INBOX]            False
# 27                      [CATEGORY_SOCIAL, INBOX]             True
# 28                     [CATEGORY_UPDATES, INBOX]             True
# 29         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 30                      [CATEGORY_SOCIAL, INBOX]             True
# 31                     [CATEGORY_UPDATES, INBOX]             True
# 32          [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 33          [IMPORTANT, CATEGORY_UPDATES, INBOX]             True
# 34          [IMPORTANT, CATEGORY_UPDATES, INBOX]             True
# 35         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 36          [IMPORTANT, CATEGORY_UPDATES, INBOX]             True
# 37         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 38         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 39          [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 40                     [CATEGORY_UPDATES, INBOX]            False
# 41          [IMPORTANT, CATEGORY_UPDATES, INBOX]             True
# 42                      [CATEGORY_SOCIAL, INBOX]             True
# 43                     [CATEGORY_UPDATES, INBOX]             True
# 44         [IMPORTANT, CATEGORY_PERSONAL, INBOX]             True
# 45          [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 46         [IMPORTANT, CATEGORY_PERSONAL, INBOX]            False
# 47          [IMPORTANT, CATEGORY_UPDATES, INBOX]            False
# 48                     [CATEGORY_UPDATES, INBOX]             True
# 49             [UNREAD, CATEGORY_UPDATES, INBOX]            False

# %%
df_spam = pd.DataFrame(spam_emails)
df_spam
# Out:
#                                                  From  \
# 0        chrono-poste-express <lrhzSOQr@cohivltyz.us>
# 1                      "FB™" <sor4yasoraya@yandex.ru>
# 2        chrono-poste-express <PTqhhPZr@rcxmjtwdz.us>
# 3     "U P S®" <Noreply-chtxZUCN@chtxzucnchtxzucn.fr>
# 4   "81OnLine_ Pres-criptionS.." <mai.so.n.07.11.2...
# 5        chrono-poste-express <vsqGzxOY@coineehma.us>
# 6        chrono-poste-express <qHNUDTOL@bhspblrqj.us>
# 7   "ups.france®" <Noreply-w6zWsvGB@w6zwsvgbw6zwsv...
# 8       "UPS®" <Noreply-r8nl3xEi@r8nl3xeir8nl3xei.fr>
# 9   "𝗙𝗘𝗗𝗘𝗫-𝗘𝘅𝗽𝗿𝗲𝘀𝘀𝗗𝗲𝗹𝗶𝘃𝗲𝗿𝘆" <DeliveryBuBKQuAt@fede...
# 10       chrono-poste-express <wgKXNqMI@vzhtzfjqu.us>
# 11  noreply <info_yknuapgf@normanedwards.onmicroso...
# 12      "UPS®" <Noreply-EMZxUnlH@emzxunlhemzxunlh.fr>
# 13  "'no-reply'" <info_xhsywvtohm@eduardopearson13...
# 14       chrono-poste-express <NQVfodyE@jjroinyzq.us>
# 15                      "'FedEx'" <ldkmKGLD@nyeni.fr>
# 16      "'Paquet en attente (1)'" <wZIdEWtR@zmizi.fr>
# 17       chrono-poste-express <YZdZgyAZ@cymxzuhgu.us>
# 18                 Team Anima <no-reply@animaapp.com>
# 19  "ups.france®" <Noreply-E5Hb9IrV@e5hb9irve5hb9i...
# 20    "Emma de Gsm55.com" <emma@newsletter.gsm55.com>
# 21         Livraison-en-cours <pGsFVtLA@jqcymhjgp.us>
# 22         "'Suivre-votre-colis'" <TiQiFgxT@xpufi.fr>
# 23    "Paquet-en-attente (1)" <tHWmPDHP@dxghrprar.us>
# 24                 Team Anima <no-reply@animaapp.com>
# 25         Livraison-en-cours <HtePeNTe@gtnjiardz.us>
# 26  "ups.france®" <Noreply-522jf9zd@522jf9zd522jf9...
# 27                 "'GLS-France'" <wTqotBAK@cksyh.fr>
# 28       chrono-poste-express <dAhNPFIp@onqhkqhnj.us>
# 29                 "'GLS-France'" <uMLdooGT@rumzg.fr>
# 30    "ᴛᴇɴᴛᴀᴛɪᴠᴇ ᴅᴇ ʟɪᴠʀᴀɪsᴏɴ" <iiEdXqjW@iiedxqjw.us>
# 31       chrono-poste-express <MfKqNMmy@gdnoclslu.us>
# 32    "Emma de Gsm55.com" <emma@newsletter.gsm55.com>
# 33       chrono-poste-express <aaQrLJij@orgvihhcl.us>
#
#                                               Subject  \
# 0   melanie.picot01, Vous avez (1) colis en attent...
# 1   📬 FB: quelqu'un a essayé de se connecter à vot...
# 2   melanie.picot01, Vous avez (1) colis en attent...
# 3   Re: UPS delivery:  melanie.picot01 votre colis...
# 4   Re: Your_Medication_DeliveredForFr e e By_Phar...
# 5   melanie.picot01, Vous avez (1) message de notr...
# 6   melanie.picot01, Vous avez (1) message de notr...
# 7   Re:  dernier chance melanie.picot01 Votre Livr...
# 8   Re: Dernier avis melanie.picot01 Votre command...
# 9   🔔melanie.picot01 ! !𝗩𝗲𝘂𝗶𝗹𝗹𝗲𝘇 𝗽𝗿𝗼𝗴𝗿𝗮𝗺𝗺𝗲𝗿 𝘂𝗻𝗲 𝗱𝗮...
# 10  melanie.picot01, Vous avez (1) message de notr...
# 11
# 12  Re: melanie.picot01 Livraison en attente de co...
# 13
# 14  melanie.picot01, Vous avez (1) message de notr...
# 15          melanie.picot01: numéro de suivi 2919****
# 16  Votre colis n'a pas pu être livré 🚚. Veuillez ...
# 17  melanie.picot01, Vous avez (1) message de notr...
# 18                 How is Anima going for you so far?
# 19  Re: melanie.picot01 Livraison en attente de co...
# 20      Jusqu'à -70% de réduction et 1 cadeau OFFERT🤩
# 21  melanie.picot01, Vous avez (1) colis en attent...
# 22  GLS : Votre colis n'a pas pu être livré 🚚. Veu...
# 23  melanie.picot01, Vous avez (1) colis en attent...
# 24    What can you expect from Anima's generated code
# 25  melanie.picot01, Vous avez reçu (1) colis en a...
# 26            Re: melanie.picot01 suivre votre colis.
# 27  melanie.picot01: 📦 Commande en attente (1). Vo...
# 28  melanie.picot01, Vous avez (1) message de notr...
# 29  melanie.picot01: 📦 Commande en attente (1). Vo...
# 30  ᴍɪsᴇ ᴀ̀ ᴊᴏᴜʀ ᴅᴇ ʟᴀ ʟɪᴠʀᴀɪsᴏɴ : ᴠᴏᴛʀᴇ ʟɪᴠʀᴀɪsᴏɴ...
# 31  melanie.picot01, Vous avez (1) message de notr...
# 32                    🌞 Soldes sur notre TOP de l'été
# 33  melanie.picot01, Vous avez (1) message de notr...
#
#                                               Snippet  \
# 0   Dépêchez-vous, temps limité Répondez au court ...
# 1   Hi , Anamul tried to log in to your account! F...
# 2   Dépêchez-vous, temps limité Répondez au court ...
# 3   UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 4
# 5   𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 6   𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 7   UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 8   UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 9   -Ce message a été envoyé par un expéditeur de ...
# 10  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 11  ************** ********** //+++++solar+++++//0...
# 12  UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 13  ************** ********** --------//solar//---...
# 14  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 15  -Ce message a été envoyé par un expéditeur de ...
# 16  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 17  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 18  Mélanie Picot, from feature wish-list to UX fe...
# 19  UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 20  1 commande = 1 Housses étanche OFFERTE * Versi...
# 21  Dépêchez-vous, temps limité Répondez au court ...
# 22  LIVRAISON DU COLIS SUSPENDU Cher [destinataire...
# 23  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 24  Anima users report they manage to complete a m...
# 25  Dépêchez-vous, temps limité Répondez au court ...
# 26  UPS SERVICE D&#39;EXPEDITION ET DE LOGISTIQUE ...
# 27  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 28  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 29  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 30  GLS. Bonjour melanie.picot01, Vous avez (1) co...
# 31  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
# 32  Coques cordons, étuis waterproof, powerbank, a...
# 33  𝗡𝗼𝘁𝗶𝗳𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗱𝗲 𝘀𝘂𝗶𝘃𝗶 𝗱𝗲 𝗹𝗮 𝗹𝗶𝘃𝗿𝗮𝗶𝘀𝗼𝗻 𝗱𝗲 𝘃𝗼𝘁𝗿𝗲...
#
#                                  Labels  Has Attachments
# 0     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 1     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 2     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 3     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 4     [UNREAD, CATEGORY_PERSONAL, SPAM]             True
# 5     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 6     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 7             [CATEGORY_PERSONAL, SPAM]            False
# 8     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 9     [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 10    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 11    [UNREAD, CATEGORY_PERSONAL, SPAM]             True
# 12    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 13      [UNREAD, CATEGORY_FORUMS, SPAM]             True
# 14    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 15    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 16    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 17    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 18     [UNREAD, CATEGORY_UPDATES, SPAM]            False
# 19    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 20  [CATEGORY_PROMOTIONS, UNREAD, SPAM]             True
# 21    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 22    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 23    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 24     [UNREAD, CATEGORY_UPDATES, SPAM]            False
# 25    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 26    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 27     [UNREAD, CATEGORY_UPDATES, SPAM]            False
# 28    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 29    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 30    [UNREAD, CATEGORY_PERSONAL, SPAM]             True
# 31    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
# 32  [CATEGORY_PROMOTIONS, UNREAD, SPAM]             True
# 33    [UNREAD, CATEGORY_PERSONAL, SPAM]            False
